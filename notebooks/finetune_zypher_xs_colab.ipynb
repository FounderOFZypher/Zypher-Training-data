# %% [markdown]
# # Fine-tune Zypher XS (Google Colab)
#
# **Architecture:** Base Model → Fine-Tune on Zypher Dataset → **Zypher XS**
#
# Base model: [poolside/Laguna-XS-2.1](https://huggingface.co/poolside/Laguna-XS-2.1) — 33B MoE coding model (3B active/token).
#
# **Runtime:** Change runtime type → **A100** (recommended) or **L4** (24 GB+).

# %%
import torch
print('CUDA:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    mem = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f'VRAM: {mem:.1f} GB')
    if mem < 20:
        print('WARNING: Zypher XS QLoRA needs ~24 GB+. Use A100 or L4 runtime.')
else:
    raise RuntimeError('Enable GPU: Runtime → Change runtime type → GPU')

# %%
REPO = 'https://github.com/FOUNDEROF-AIRIES-AGENT/Zypher-Training-data.git'
BRANCH = 'cursor/llm-finetune-ready-da1e'

# !rm -rf Zypher-Training-data
# !git clone --branch {BRANCH} --single-branch {REPO}
# %cd Zypher-Training-data

# %%
# !pip install -q -r requirements.txt
# !pip install -q -U transformers accelerate peft trl bitsandbytes

# %%
# Hugging Face login (required — accept Laguna license on HF first)
from huggingface_hub import notebook_login
notebook_login()

# %%
# !make generate-smoke
# !make prepare
# !python3 scripts/validate_pipeline.py

# %% [markdown]
# ## Fine-tune Laguna XS 2.1 → Zypher XS (QLoRA)
#
# Uses `config/zypher_xs.yaml`. First run downloads the base model (~66 GB on disk; 4-bit loads a subset into VRAM).

# %%
# !python3 scripts/train.py --config config/zypher_xs.yaml

# %%
# !python3 scripts/infer.py \
  --base-model poolside/Laguna-XS-2.1 \
  --adapter outputs/zypher-xs/final \
  --question "Explain GraphRAG for code architecture."

# %%
# !zip -r zypher-xs-adapter.zip outputs/zypher-xs/final
from google.colab import files
files.download('zypher-xs-adapter.zip')
